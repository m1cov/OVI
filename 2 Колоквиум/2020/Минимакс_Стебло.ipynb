# %% [markdown]
# # Втор парцијален испит по Основи на Вештачката Интелигенција

# %% [markdown]
# ## Задача 1

# %% [markdown]
# **(35 поени)** На сликата е прикажано стеблото на некоја хипотетичка игра со нулта сума. МАХ јазлите во стеблото се означени со квадрати, додека МIN јазлите се претставени со кругчиња. Листовите во стеблото ги претставуваат вредностите на играта од аспект на МАХ играчот. Броевите крај јазлите го претставуваат редоследот во кој јазлите се разгледувани од страна на МIN -МАХ и АЛФА-БЕТА алгоритмите.

# %%
from IPython import display
display.Image('images/minmax.png', width=720)

# %% [markdown]
# 1. Да се означат вредностите на јазлите според МIN-МАХ алгоритамот и потезите кои ќе ги влечат играчите. Под претпоставка, играчите играат оптимално.
# 1. Да се одредат јазлите кои нема да бидат испитувани, односно гранките кои ќе бидат “отсечени“ со АЛФА-БЕТА алгоритамот.

# %% [markdown]
# ## Решение

# %%
display.Image('images/reshenie_zad1.jpg', width=720)
